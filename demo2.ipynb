# %%
import gurobipy as grb
import numpy as np
from scipy.stats import spearmanr
import os
import scanpy as sc
import pandas as pd



def gene_gene_correlation(X, method = 'spearman'):
    """
    Compute the gene-gene correlation matrix from the gene expression matrix X.

    Args:
        X (np.ndarray or List[np.ndarray]): A matrix of shape (N, d), where N is the number of cells/spots and d is the number of genes. 
            Alternatively, a list of such matrices (from different batches/samples) with consistent gene dimensions.
        method (str): Method used to compute correlation. Must be either 'spearman' or 'pearson'.

    Returns:
        np.ndarray: A gene-gene correlation matrix of shape (d, d).
    """

    if type(X) ==list:
        corr_mat_list = []
        for x in X:
            if method == 'spearman':
                corr_mat, _ = spearmanr(x)
            if method == 'pearson':
                corr_mat = np.corrcoef(x.T)
            corr_mat_list.append(corr_mat)  
        corr_mat = np.vstack(corr_mat_list)
    else :
        if method == 'spearman':
            corr_mat, _ = spearmanr(X)
        if method == 'pearson':
            corr_mat = np.corrcoef(X.T)
    return corr_mat


def covering(Z, minSize=1, alpha=0.05, weights = 1., output=None, callBack = None,
             poolSolutions=None, poolSearchMode=None, poolGap = None, timeLimit=None, LogToConsole= 1,restart=None):
    """
    Solves a weighted gene selection problem using a Gurobi-based optimization model.

    Args:
        Z (np.ndarray): A binary matrix of shape (N, d), where N is the number of samples and d is the number of genes.
        minSize (int): The minimum number of genes to select.
        alpha (float): The minimum fraction of samples that must be covered.
        weights (np.ndarray): A 1D array of weights for each gene. Higher weights indicate higher cost for selection.
        output (int): Enables or disables solver output. Set to 1 to print optimization details, 0 to suppress.
        callBack (Callable): A callback function to be invoked during optimization.
        poolSolutions (int): Number of solutions to store in the solution pool. See: https://www.gurobi.com/documentation/current/refman/poolsolutions.html
        poolSearchMode (int): Mode for exploring the MIP search tree. See: https://www.gurobi.com/documentation/current/refman/poolsearchmode.html
        poolGap (float): Relative MIP optimality gap for accepting solutions into the pool. See:https://www.gurobi.com/documentation/current/refman/poolgap.html
        timeLimit (float): Time limit (in seconds) for the optimization run.
        LogToConsole (int): Whether to print the optimization log. Set to 1 to enable.
        restart (gurobipy.Model): A Gurobi model instance to restart the optimization from.

    Returns:
        List[int]: Indices of the selected genes.
    """

    if restart is not None:
        cov = restart
        if output is not None:
            cov.Params.OutputFlag = output
        if poolSolutions is not None:
            cov.Params.PoolSolutions = poolSolutions
        if poolSearchMode is not None:
            cov.Params.PoolSearchMode = poolSearchMode
        if poolGap is not None:
            cov.Params.PoolGap = poolGap
        if timeLimit is not None:
            cov.Params.TimeLimit = timeLimit
        if LogToConsole is not None:
            cov.Params.LogToConsole = LogToConsole
        if callBack is None:
            cov.optimize()
        else:
            cov.optimize(callBack)
        return cov

    if np.isscalar(minSize):
        minSize = [minSize]
    if np.isscalar(alpha):
        alpha = [alpha]*len(minSize)
    N = Z.shape[0]
    d = Z.shape[1]
    if type(weights) == str and weights=='prob':
        w = 1 - 0.01 * np.mean(Z, axis=0)
    elif np.isscalar(weights):
        w = weights * np.ones(d)
    else:
        w = weights
    cov = grb.Model()
    if output is not None:
        cov.Params.OutputFlag=output
    if poolSolutions is not None:
        cov.Params.PoolSolutions = poolSolutions
    if poolSearchMode is not None:
        cov.Params.PoolSearchMode = poolSearchMode
    if poolGap is not None:
        cov.Params.PoolGap = poolGap
    if timeLimit is not None:
        cov.Params.TimeLimit = timeLimit
    if LogToConsole is not None:
        cov.Params.LogToConsole = LogToConsole

    nlevels = len(minSize)
    x = []
    y = []
    for l in range(nlevels):
        x.append(cov.addMVar(d, vtype=grb.GRB.BINARY))
    for l in range(nlevels):
        y.append(cov.addMVar(N, vtype=grb.GRB.BINARY))

    for l in range(nlevels):
        expr = y[l].sum()
        cov.addConstr(expr >= N*(1-alpha[l]), 'Coverage_'+str(l))

    for l in range(nlevels):
        expr = Z @ x[l] - minSize[l]*y[l]
        cov.addConstr(expr >= 0, 'covered_' + str(l))

        # if B is not None:
        #     exprB = B @ x[l] - MinMarkerPerClass
        #     cov.addConstr(exprB >= 0, 'MinMarkerPerClass_' + str(l))

    for l in range(nlevels-1):
        for j in range(d):
            cov.addConstr(x[l+1].tolist()[j] - x[l].tolist()[j] >= 0, name= 'Nesting'+str(j)+'_'+str(l))

    expr = grb.LinExpr()
    for l in range(nlevels):
        expr += (w * x[l]).sum()
    cov.setObjective(expr, grb.GRB.MINIMIZE)
    if callBack is None:
        cov.optimize()
    else:
        cov.optimize(callBack)
    return cov


def greedy_weighted_set_cover(Z, w) :
    """
    Greedy heuristic for the weighted set cover problem.

    Args:
        Z (np.ndarray): A binary matrix of shape (n_elements, m_sets), where `Z[i, j] == 1` 
            indicates that set `j` covers element `i`.
        w (np.ndarray): A 1D array of length `m_sets` representing the weight of each set.

    Returns:
        List[int]: Indices of the selected sets (column indices of `Z`) that form a cover.
    """

    n, m = Z.shape
    # which elements are still uncovered
    uncovered = np.ones(n, dtype=bool)
    # which sets are still available
    available = np.ones(m, dtype=bool)
    selected = []

    while uncovered.any():
        # For each set j: how many of the still-uncovered elements it would cover?
        # Z[uncovered] is an array of shape (#uncovered_elements, m)
        cover_counts = Z[uncovered].sum(axis=0)  # shape (m,)
        # zero out the ones we've already taken
        cover_counts = np.where(available, cover_counts, 0)

        # fast-path: if the best we can do is cover exactly one element per set,
        # grab them all at once and be done
        if cover_counts.max() == Z.shape[0] // Z.shape[1]:
            singletons = np.where((available) & (cover_counts == 1))[0]
            selected.extend(singletons.tolist())
            break

        # otherwise pick the set with max (covered_new_elems / weight)
        nonzero = cover_counts > 0
        if not nonzero.any():
            # nothing left can cover any new element
            break

        ratios = np.zeros(m, dtype=float)
        ratios[nonzero] = cover_counts[nonzero] / w[nonzero]
        best = int(ratios.argmax())
        selected.append(best)

        # mark its covered elements as now covered
        # Z[:, best] is the column for set "best"
        uncovered &= ~Z[:, best].astype(bool)
        # and remove that set from future consideration
        available[best] = False
        print(uncovered.sum(), "elements left uncovered, selected")
    return selected



def GeneCover(num_marker, corr_mat, w, m = 3,interval = 0, lambdaMax = .3, lambdaMin = 0.05, timeLimit = 600, output = 0, greedy =False) :
    """
    Selects marker genes based on gene-gene correlation using combinatorial optimization or a greedy heuristic.

    Args:
        num_marker (int): Desired number of markers to select.
        corr_mat (np.ndarray): Gene-gene correlation matrix.
        interval (int): Allowed deviation from `num_marker`. The final number of markers may vary within this range.
        w (np.ndarray): An array of weights for the genes. Higher weights indicate higher cost for selection.
        lambdaMax (float): Maximum threshold for acceptable gene-gene correlation.
        lambdaMin (float): Minimum threshold for acceptable gene-gene correlation.
        timeLimit (float): Time limit (in seconds) for the optimization.
        ouput (int): Whether to print the optimization process. Set to 1 to enable.
        greedy (bool): Whether to use a greedy algorithm for set cover instead of the Gurobi solver. Default: False.

    Returns:
        List[int]: Indices of the selected marker genes.
    """

    epsilon = (lambdaMax + lambdaMin)/2
    best_marker_length_gap = 1e6
    selection = np.arange(corr_mat.shape[1])
    G_v3 = corr_mat > epsilon
    if not greedy:
        cov_sol = covering(G_v3, minSize=1, alpha=0.0, weights=w, timeLimit=timeLimit, output = output)
        cov_sol = selection[np.array(cov_sol.x)[:len(selection)] > 0.5]
    else:
        cov_sol = greedy_weighted_set_cover(G_v3, w)
    markers = []
    num_batches = G_v3.shape[0] // G_v3.shape[1]
    num_genes = G_v3.shape[1]
    for i in cov_sol:
        if num_batches > 1:
            if G_v3[[i + j * num_genes for j in range(num_batches)]].sum(axis = 1).min() >= m:
                markers.append(i)
        else:
            if G_v3[i].sum() >= m:
                markers.append(i)
    n_markers = len(markers)
    current_gap = abs(n_markers - num_marker)
    best_marker_length_gap = current_gap
    best_epsilon = epsilon
    while (lambdaMax - lambdaMin) > 1e-6 and (n_markers < num_marker or n_markers > num_marker + interval):
        print(lambdaMin, lambdaMax, n_markers, num_marker, current_gap)
        if n_markers< num_marker:
            lambdaMax = epsilon
        else:
            lambdaMin = epsilon
        epsilon = (lambdaMin+lambdaMax)/2
        G_v3 = corr_mat > epsilon
        if not greedy:
            cov_sol = covering(G_v3, minSize=1, alpha=0.0, weights=w, timeLimit=timeLimit,output = output)
            cov_sol = selection[np.array(cov_sol.x)[:len(selection)] > 0.5]
        else:
            cov_sol = greedy_weighted_set_cover(G_v3, w)
        markers = []
        for i in cov_sol:
            if num_batches > 1:
                if G_v3[[i + j * num_genes for j in range(num_batches)]].sum(axis = 1).min() >= m:
                    markers.append(i)
            else:
                if G_v3[i].sum() >= m:
                    markers.append(i)
            n_markers = len(markers)

        current_gap = abs(n_markers - num_marker)
        if current_gap < best_marker_length_gap:
            best_marker_length_gap = current_gap
            best_epsilon = epsilon
            best_lambdaMin = lambdaMin
            best_lambdaMax = lambdaMax
            best_direction = n_markers < num_marker
    print("Best Gap: ", best_marker_length_gap)
    print("Best Epsilon: ", best_epsilon)
    return markers

def Iterative_GeneCover(incremental_sizes,corr_mat, w,m = 3, lambdaMin = .05,lambdaMax = .3, timeLimit = 600, output = 0, greedy = False):
    
    """
    Performs iterative marker gene selection using the GeneCover algorithm.

    Args:
        corr_mat (np.ndarray): Gene-gene correlation matrix of shape (d, d).
        incremental_sizes (List[int]): A list indicating the number of markers to select at each iteration.
        w (np.ndarray): An array of weights for each gene. Higher weights indicate higher cost for selection.
        lambdaMax (float): Maximum threshold for gene-gene correlation.
        lambdaMin (float): Minimum threshold for gene-gene correlation.
        timeLimit (float): Time limit (in seconds) for the optimization.
        output (int): Whether to print the optimization process. Set to 1 to enable.
        greedy (bool): Whether to use the greedy set cover algorithm instead of the Gurobi solver. Default: False.

    Returns:
        List[List[int]]: A list where each element is a list of indices of the selected marker genes at the corresponding iteration.
    """
    num_batches = corr_mat.shape[0] // corr_mat.shape[1]
    num_genes = corr_mat.shape[1]
    MARKERS = []
    print("Iteration 1")
    markers = GeneCover(incremental_sizes[0], corr_mat, w = w, m =m, lambdaMax = lambdaMax, lambdaMin = lambdaMin, timeLimit = timeLimit, output=output, greedy=greedy)
    selection = np.arange(corr_mat.shape[1])  
    MARKERS.append(markers)
    remaining_genes_idx_abs = np.setdiff1d(selection, markers)
    for t, size in enumerate(incremental_sizes[1:]): 
        print("Iteration ", t+2)
        remaining_genes_idx_abs_batches = np.array([remaining_genes_idx_abs + j * num_genes for j in range(num_batches)]).flatten()
        corr_mat_remain = corr_mat[remaining_genes_idx_abs_batches][:,remaining_genes_idx_abs]
        markers = GeneCover(size, corr_mat_remain, w = w[remaining_genes_idx_abs], m =m, lambdaMin= lambdaMin,lambdaMax=lambdaMax, timeLimit = timeLimit, output=output, greedy=greedy)
        MARKERS.append(remaining_genes_idx_abs[markers])
        remaining_genes_idx_abs = np.setdiff1d(remaining_genes_idx_abs, [j for i in MARKERS for j in i])  
    return MARKERS

# %%
os.getcwd()
# Out:
# 'c:\\Users\\An Wang\\Desktop\\GeneCover'

# %%
Adata = {}
data_dir = "data\\DLPFC Full Samples"
file_names = os.listdir(data_dir)
across_samples_file_names = file_names[:3]
annotation_names = file_names[3:]
for j,  file in enumerate(across_samples_file_names):
    adata = sc.read_10x_h5(os.path.join(data_dir, file))
    adata.var_names_make_unique()
    layer_annotation = pd.read_csv(os.path.join(data_dir, annotation_names[j]), index_col=0)
    assert np.all(adata.obs.index.values == layer_annotation.index.values)
    adata.obs = layer_annotation
    sc.pp.filter_genes(adata, min_cells=100)
    sc.pp.normalize_total(adata, target_sum=1e4)
    sc.pp.log1p(adata)
    sc.pp.highly_variable_genes(adata, n_top_genes=10000)
    adata = adata[:, adata.var.highly_variable]
    Adata[file.split("_")[0]] = adata

for j, file in enumerate(across_samples_file_names):
    if j == 0: 
        genes_across_samples = Adata[file.split("_")[0]].var_names.values
    else:
        genes_across_samples = np.intersect1d(genes_across_samples, Adata[file.split("_")[0]].var_names.values)

for key in across_samples_file_names:
    Adata[key.split("_")[0]] = Adata[key.split("_")[0]][:, genes_across_samples]
# Out:
# c:\Users\An Wang\.conda\envs\vae-spatial\lib\site-packages\anndata\_core\anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# c:\Users\An Wang\.conda\envs\vae-spatial\lib\site-packages\anndata\_core\anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# c:\Users\An Wang\.conda\envs\vae-spatial\lib\site-packages\anndata\_core\anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# c:\Users\An Wang\.conda\envs\vae-spatial\lib\site-packages\anndata\_core\anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# c:\Users\An Wang\.conda\envs\vae-spatial\lib\site-packages\anndata\_core\anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# c:\Users\An Wang\.conda\envs\vae-spatial\lib\site-packages\anndata\_core\anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
corr_mat_combine_across_samples = gene_gene_correlation([Adata[key.split("_")[0]].X.toarray() for key in across_samples_file_names])

# %%
corr_mat_combine_across_samples.shape
# Out:
# (25500, 8500)

# %%
# Obtain 200 marker genes via Iterative GeneCover with an incremental size of 100 and two iterations
genecover_marker_across_samples_greedy = genecover_markers_iterative = Iterative_GeneCover(incremental_sizes=[100,100], corr_mat=corr_mat_combine_across_samples, w=np.ones(corr_mat_combine_across_samples.shape[1]), greedy=True)
# Out:
# Iteration 1
# 24996 elements left uncovered, selected
# 24696 elements left uncovered, selected
# 24585 elements left uncovered, selected
# 24521 elements left uncovered, selected
# 24470 elements left uncovered, selected
# 24444 elements left uncovered, selected
# 24422 elements left uncovered, selected
# 24401 elements left uncovered, selected
# 24381 elements left uncovered, selected
# 24365 elements left uncovered, selected
# 24349 elements left uncovered, selected
# 24335 elements left uncovered, selected
# 24322 elements left uncovered, selected
# 24309 elements left uncovered, selected
# 24297 elements left uncovered, selected
# 24286 elements left uncovered, selected
# 24277 elements left uncovered, selected
# 24270 elements left uncovered, selected
# 24263 elements left uncovered, selected
# 24257 elements left uncovered, selected
# 24252 elements left uncovered, selected
# 24247 elements left uncovered, selected
# 24242 elements left uncovered, selected
# 24237 elements left uncovered, selected
# 24232 elements left uncovered, selected
# 24228 elements left uncovered, selected
# 24224 elements left uncovered, selected
# 24220 elements left uncovered, selected
# 24216 elements left uncovered, selected
# 24212 elements left uncovered, selected
# 24208 elements left uncovered, selected
# 24204 elements left uncovered, selected
# 24200 elements left uncovered, selected
# 24196 elements left uncovered, selected
# 24192 elements left uncovered, selected
# 24189 elements left uncovered, selected
# 24186 elements left uncovered, selected
# 24183 elements left uncovered, selected
# 24180 elements left uncovered, selected
# 24177 elements left uncovered, selected
# 24174 elements left uncovered, selected
# 24171 elements left uncovered, selected
# 24168 elements left uncovered, selected
# 24165 elements left uncovered, selected
# 24162 elements left uncovered, selected
# 24159 elements left uncovered, selected
# 24156 elements left uncovered, selected
# 24153 elements left uncovered, selected
# 24150 elements left uncovered, selected
# 24147 elements left uncovered, selected
# 24144 elements left uncovered, selected
# 24141 elements left uncovered, selected
# 24138 elements left uncovered, selected
# 24135 elements left uncovered, selected
# 24132 elements left uncovered, selected
# 24129 elements left uncovered, selected
# 24126 elements left uncovered, selected
# 24123 elements left uncovered, selected
# 24120 elements left uncovered, selected
# 24117 elements left uncovered, selected
# 24114 elements left uncovered, selected
# 24111 elements left uncovered, selected
# 24108 elements left uncovered, selected
# 24105 elements left uncovered, selected
# 24102 elements left uncovered, selected
# 24099 elements left uncovered, selected
# 24096 elements left uncovered, selected
# 24093 elements left uncovered, selected
# 24090 elements left uncovered, selected
# 24087 elements left uncovered, selected
# 24084 elements left uncovered, selected
# 24081 elements left uncovered, selected
# 24078 elements left uncovered, selected
# 24075 elements left uncovered, selected
# 24072 elements left uncovered, selected
# 24069 elements left uncovered, selected
# 24066 elements left uncovered, selected
# 24063 elements left uncovered, selected
# 24060 elements left uncovered, selected
# 24057 elements left uncovered, selected
# 24054 elements left uncovered, selected
# 24051 elements left uncovered, selected
# 24048 elements left uncovered, selected
# 24045 elements left uncovered, selected
# 24042 elements left uncovered, selected
# 24039 elements left uncovered, selected
# 24036 elements left uncovered, selected
# 24033 elements left uncovered, selected
# 24030 elements left uncovered, selected
# 24027 elements left uncovered, selected
# 24024 elements left uncovered, selected
# 24021 elements left uncovered, selected
# 24018 elements left uncovered, selected
# 24015 elements left uncovered, selected
# 24012 elements left uncovered, selected
# 24009 elements left uncovered, selected
# 24006 elements left uncovered, selected
# 24003 elements left uncovered, selected
# 24000 elements left uncovered, selected
# 23997 elements left uncovered, selected
# 23994 elements left uncovered, selected
# 23991 elements left uncovered, selected
# 23988 elements left uncovered, selected
# 23985 elements left uncovered, selected
# 23982 elements left uncovered, selected
# 23979 elements left uncovered, selected
# 23976 elements left uncovered, selected
# 23973 elements left uncovered, selected
# 23970 elements left uncovered, selected
# 23967 elements left uncovered, selected
# 23964 elements left uncovered, selected
# 23961 elements left uncovered, selected
# 23958 elements left uncovered, selected
# 23955 elements left uncovered, selected
# 23952 elements left uncovered, selected
# 23949 elements left uncovered, selected
# 23946 elements left uncovered, selected
# 23943 elements left uncovered, selected
# 23940 elements left uncovered, selected
# 23937 elements left uncovered, selected
# 23934 elements left uncovered, selected
# 23931 elements left uncovered, selected
# 23928 elements left uncovered, selected
# 23925 elements left uncovered, selected
# 23922 elements left uncovered, selected
# 23919 elements left uncovered, selected
# 23916 elements left uncovered, selected
# 23913 elements left uncovered, selected
# 23910 elements left uncovered, selected
# 23907 elements left uncovered, selected
# 23904 elements left uncovered, selected
# 23901 elements left uncovered, selected
# 23898 elements left uncovered, selected
# 23895 elements left uncovered, selected
# 23892 elements left uncovered, selected
# 23889 elements left uncovered, selected
# 23886 elements left uncovered, selected
# 23883 elements left uncovered, selected
# 23880 elements left uncovered, selected
# 23877 elements left uncovered, selected
# 23874 elements left uncovered, selected
# 23871 elements left uncovered, selected
# 23868 elements left uncovered, selected
# 23865 elements left uncovered, selected
# 23862 elements left uncovered, selected
# 23859 elements left uncovered, selected
# 23856 elements left uncovered, selected
# 23853 elements left uncovered, selected
# 23850 elements left uncovered, selected
# 23847 elements left uncovered, selected
# 23844 elements left uncovered, selected
# 23841 elements left uncovered, selected
# 23838 elements left uncovered, selected
# 23835 elements left uncovered, selected
# 23832 elements left uncovered, selected
# 23829 elements left uncovered, selected
# 23826 elements left uncovered, selected
# 23823 elements left uncovered, selected
# 23820 elements left uncovered, selected
# 23817 elements left uncovered, selected
# 23814 elements left uncovered, selected
# 23811 elements left uncovered, selected
# 23808 elements left uncovered, selected
# 23805 elements left uncovered, selected
# 23802 elements left uncovered, selected
# 23799 elements left uncovered, selected
# 23796 elements left uncovered, selected
# 23793 elements left uncovered, selected
# 23790 elements left uncovered, selected
# 23787 elements left uncovered, selected
# 23784 elements left uncovered, selected
# 23781 elements left uncovered, selected
# 23778 elements left uncovered, selected
# 23775 elements left uncovered, selected
# 23772 elements left uncovered, selected
# 23769 elements left uncovered, selected
# 23766 elements left uncovered, selected
# 23763 elements left uncovered, selected
# 23760 elements left uncovered, selected
# 23757 elements left uncovered, selected
# 23754 elements left uncovered, selected
# 23751 elements left uncovered, selected
# 23748 elements left uncovered, selected
# 23745 elements left uncovered, selected
# 23742 elements left uncovered, selected
# 23739 elements left uncovered, selected
# 23736 elements left uncovered, selected
# 23733 elements left uncovered, selected
# 23730 elements left uncovered, selected
# 23727 elements left uncovered, selected
# 23724 elements left uncovered, selected
# 23721 elements left uncovered, selected
# 23718 elements left uncovered, selected
# 23715 elements left uncovered, selected
# 23712 elements left uncovered, selected
# 23709 elements left uncovered, selected
# 23706 elements left uncovered, selected
# 23703 elements left uncovered, selected
# 23700 elements left uncovered, selected
# 23697 elements left uncovered, selected
# 23694 elements left uncovered, selected
# 23691 elements left uncovered, selected
# 23688 elements left uncovered, selected
# 23685 elements left uncovered, selected
# 23682 elements left uncovered, selected
# 23679 elements left uncovered, selected
# 23676 elements left uncovered, selected
# 23673 elements left uncovered, selected
# 23670 elements left uncovered, selected
# 23667 elements left uncovered, selected
# 23664 elements left uncovered, selected
# 23661 elements left uncovered, selected
# 23658 elements left uncovered, selected
# 23655 elements left uncovered, selected
# 23652 elements left uncovered, selected
# 23649 elements left uncovered, selected
# 23646 elements left uncovered, selected
# 23643 elements left uncovered, selected
# 23640 elements left uncovered, selected
# 23637 elements left uncovered, selected
# 23634 elements left uncovered, selected
# 23631 elements left uncovered, selected
# 23628 elements left uncovered, selected
# 23625 elements left uncovered, selected
# 23622 elements left uncovered, selected
# 23619 elements left uncovered, selected
# 23616 elements left uncovered, selected
# 23613 elements left uncovered, selected
# 23610 elements left uncovered, selected
# 23607 elements left uncovered, selected
# 23604 elements left uncovered, selected
# 23601 elements left uncovered, selected
# 23598 elements left uncovered, selected
# 23595 elements left uncovered, selected
# 23592 elements left uncovered, selected
# 23589 elements left uncovered, selected
# 23586 elements left uncovered, selected
# 23583 elements left uncovered, selected
# 23580 elements left uncovered, selected
# 23577 elements left uncovered, selected
# 23574 elements left uncovered, selected
# 23571 elements left uncovered, selected
# 23568 elements left uncovered, selected
# 23565 elements left uncovered, selected
# 23562 elements left uncovered, selected
# 23559 elements left uncovered, selected
# 23556 elements left uncovered, selected
# 23553 elements left uncovered, selected
# 23550 elements left uncovered, selected
# 23547 elements left uncovered, selected
# 23544 elements left uncovered, selected
# 23541 elements left uncovered, selected
# 23538 elements left uncovered, selected
# 23535 elements left uncovered, selected
# 23532 elements left uncovered, selected
# 23529 elements left uncovered, selected
# 23526 elements left uncovered, selected
# 23523 elements left uncovered, selected
# 23520 elements left uncovered, selected
# 23517 elements left uncovered, selected
# 23514 elements left uncovered, selected
# 23511 elements left uncovered, selected
# 23508 elements left uncovered, selected
# 23505 elements left uncovered, selected
# 23502 elements left uncovered, selected
# 23499 elements left uncovered, selected
# 23496 elements left uncovered, selected
# 23493 elements left uncovered, selected
# 23490 elements left uncovered, selected
# 23487 elements left uncovered, selected
# 23484 elements left uncovered, selected
# 23481 elements left uncovered, selected
# 23478 elements left uncovered, selected
# 23475 elements left uncovered, selected
# 23472 elements left uncovered, selected
# 23469 elements left uncovered, selected
# 23466 elements left uncovered, selected
# 23463 elements left uncovered, selected
# 23460 elements left uncovered, selected
# 23457 elements left uncovered, selected
# 23454 elements left uncovered, selected
# 23451 elements left uncovered, selected
# 23448 elements left uncovered, selected
# 23445 elements left uncovered, selected
# 23442 elements left uncovered, selected
# 23439 elements left uncovered, selected
# 23436 elements left uncovered, selected
# 23433 elements left uncovered, selected
# 23430 elements left uncovered, selected
# 23427 elements left uncovered, selected
# 23424 elements left uncovered, selected
# 23421 elements left uncovered, selected
# 23418 elements left uncovered, selected
# 23415 elements left uncovered, selected
# 23412 elements left uncovered, selected
# 23409 elements left uncovered, selected
# 23406 elements left uncovered, selected
# 23403 elements left uncovered, selected
# 23400 elements left uncovered, selected
# 23397 elements left uncovered, selected
# 23394 elements left uncovered, selected
# 23391 elements left uncovered, selected
# 23388 elements left uncovered, selected
# 23385 elements left uncovered, selected
# 23382 elements left uncovered, selected
# 23379 elements left uncovered, selected
# 23376 elements left uncovered, selected
# 23373 elements left uncovered, selected
# 23370 elements left uncovered, selected
# 23367 elements left uncovered, selected
# 23364 elements left uncovered, selected
# 23361 elements left uncovered, selected
# 23358 elements left uncovered, selected
# 23355 elements left uncovered, selected
# 23352 elements left uncovered, selected
# 23349 elements left uncovered, selected
# 23346 elements left uncovered, selected
# 23343 elements left uncovered, selected
# 23340 elements left uncovered, selected
# 23337 elements left uncovered, selected
# 23334 elements left uncovered, selected
# 23331 elements left uncovered, selected
# 23328 elements left uncovered, selected
# 23325 elements left uncovered, selected
# 23322 elements left uncovered, selected
# 23319 elements left uncovered, selected
# 23316 elements left uncovered, selected
# 23313 elements left uncovered, selected
# 23310 elements left uncovered, selected
# 23307 elements left uncovered, selected
# 23304 elements left uncovered, selected
# 23301 elements left uncovered, selected
# 23298 elements left uncovered, selected
# 23295 elements left uncovered, selected
# 23292 elements left uncovered, selected
# 23289 elements left uncovered, selected
# 23286 elements left uncovered, selected
# 23283 elements left uncovered, selected
# 23280 elements left uncovered, selected
# 23277 elements left uncovered, selected
# 23274 elements left uncovered, selected
# 23271 elements left uncovered, selected
# 23268 elements left uncovered, selected
# 23265 elements left uncovered, selected
# 23262 elements left uncovered, selected
# 23259 elements left uncovered, selected
# 23256 elements left uncovered, selected
# 23253 elements left uncovered, selected
# 23250 elements left uncovered, selected
# 23247 elements left uncovered, selected
# 23244 elements left uncovered, selected
# 23241 elements left uncovered, selected
# 23238 elements left uncovered, selected
# 23235 elements left uncovered, selected
# 23232 elements left uncovered, selected
# 23229 elements left uncovered, selected
# 23226 elements left uncovered, selected
# 23223 elements left uncovered, selected
# 23220 elements left uncovered, selected
# 23217 elements left uncovered, selected
# 23214 elements left uncovered, selected
# 23211 elements left uncovered, selected
# 23208 elements left uncovered, selected
# 23205 elements left uncovered, selected
# 23202 elements left uncovered, selected
# 23199 elements left uncovered, selected
# 23196 elements left uncovered, selected
# 23193 elements left uncovered, selected
# 23190 elements left uncovered, selected
# 23187 elements left uncovered, selected
# 23184 elements left uncovered, selected
# 23181 elements left uncovered, selected
# 23178 elements left uncovered, selected
# 23175 elements left uncovered, selected
# 23172 elements left uncovered, selected
# 23169 elements left uncovered, selected
# 23166 elements left uncovered, selected
# 23163 elements left uncovered, selected
# 23160 elements left uncovered, selected
# 23157 elements left uncovered, selected
# 23154 elements left uncovered, selected
# 23151 elements left uncovered, selected
# 23148 elements left uncovered, selected
# 23145 elements left uncovered, selected
# 23142 elements left uncovered, selected
# 23139 elements left uncovered, selected
# 23136 elements left uncovered, selected
# 23133 elements left uncovered, selected
# 23130 elements left uncovered, selected
# 23127 elements left uncovered, selected
# 23124 elements left uncovered, selected
# 23121 elements left uncovered, selected
# 23118 elements left uncovered, selected
# 23115 elements left uncovered, selected
# 23112 elements left uncovered, selected
# 23109 elements left uncovered, selected
# 23106 elements left uncovered, selected
# 23103 elements left uncovered, selected
# 23100 elements left uncovered, selected
# 23097 elements left uncovered, selected
# 23094 elements left uncovered, selected
# 23091 elements left uncovered, selected
# 23088 elements left uncovered, selected
# 23085 elements left uncovered, selected
# 23082 elements left uncovered, selected
# 23079 elements left uncovered, selected
# 23076 elements left uncovered, selected
# 23073 elements left uncovered, selected
# 23070 elements left uncovered, selected
# 23067 elements left uncovered, selected
# 23064 elements left uncovered, selected
# 23061 elements left uncovered, selected
# 23058 elements left uncovered, selected
# 23055 elements left uncovered, selected
# 23052 elements left uncovered, selected
# 23049 elements left uncovered, selected
# 23046 elements left uncovered, selected
# 23043 elements left uncovered, selected
# 23040 elements left uncovered, selected
# 23037 elements left uncovered, selected
# 23034 elements left uncovered, selected
# 23031 elements left uncovered, selected
# 23028 elements left uncovered, selected
# 23025 elements left uncovered, selected
# 23022 elements left uncovered, selected
# 23019 elements left uncovered, selected
# 23016 elements left uncovered, selected
# 23013 elements left uncovered, selected
# 23010 elements left uncovered, selected
# 23007 elements left uncovered, selected
# 23004 elements left uncovered, selected
# 23001 elements left uncovered, selected
# 22998 elements left uncovered, selected
# 22995 elements left uncovered, selected
# 22992 elements left uncovered, selected
# 22989 elements left uncovered, selected
# 22986 elements left uncovered, selected
# 22983 elements left uncovered, selected
# 22980 elements left uncovered, selected
# 22977 elements left uncovered, selected
# 22974 elements left uncovered, selected
# 22971 elements left uncovered, selected
# 22968 elements left uncovered, selected
# 22965 elements left uncovered, selected
# 22962 elements left uncovered, selected
# 22959 elements left uncovered, selected
# 22956 elements left uncovered, selected
# 22953 elements left uncovered, selected
# 22950 elements left uncovered, selected
# 22947 elements left uncovered, selected
# 22944 elements left uncovered, selected
# 22941 elements left uncovered, selected
# 22938 elements left uncovered, selected
# 22935 elements left uncovered, selected
# 22932 elements left uncovered, selected
# 22929 elements left uncovered, selected
# 22926 elements left uncovered, selected
# 22923 elements left uncovered, selected
# 22920 elements left uncovered, selected
# 22917 elements left uncovered, selected
# 22914 elements left uncovered, selected
# 22911 elements left uncovered, selected
# 22908 elements left uncovered, selected
# 22905 elements left uncovered, selected
# 22902 elements left uncovered, selected
# 22899 elements left uncovered, selected
# 22896 elements left uncovered, selected
# 22893 elements left uncovered, selected
# 22890 elements left uncovered, selected
# 22887 elements left uncovered, selected
# 22884 elements left uncovered, selected
# 22881 elements left uncovered, selected
# 22878 elements left uncovered, selected
# 22875 elements left uncovered, selected
# 22872 elements left uncovered, selected
# 22869 elements left uncovered, selected
# 22866 elements left uncovered, selected
# 22863 elements left uncovered, selected
# 22860 elements left uncovered, selected
# 22857 elements left uncovered, selected
# 22854 elements left uncovered, selected
# 22851 elements left uncovered, selected
# 22848 elements left uncovered, selected
# 22845 elements left uncovered, selected
# 22842 elements left uncovered, selected
# 22839 elements left uncovered, selected
# 22836 elements left uncovered, selected
# 22833 elements left uncovered, selected
# 22830 elements left uncovered, selected
# 22827 elements left uncovered, selected
# 22824 elements left uncovered, selected
# 22821 elements left uncovered, selected
# 22818 elements left uncovered, selected
# 22815 elements left uncovered, selected
# 22812 elements left uncovered, selected
# 22809 elements left uncovered, selected
# 22806 elements left uncovered, selected
# 22803 elements left uncovered, selected
# 22800 elements left uncovered, selected
# 22797 elements left uncovered, selected
# 22794 elements left uncovered, selected
# 22791 elements left uncovered, selected
# 22788 elements left uncovered, selected
# 22785 elements left uncovered, selected
# 22782 elements left uncovered, selected
# 22779 elements left uncovered, selected
# 22776 elements left uncovered, selected
# 22773 elements left uncovered, selected
# 22770 elements left uncovered, selected
# 22767 elements left uncovered, selected
# 22764 elements left uncovered, selected
# 22761 elements left uncovered, selected
# 22758 elements left uncovered, selected
# 22755 elements left uncovered, selected
# 22752 elements left uncovered, selected
# 22749 elements left uncovered, selected
# 22746 elements left uncovered, selected
# 22743 elements left uncovered, selected
# 22740 elements left uncovered, selected
# 22737 elements left uncovered, selected
# 22734 elements left uncovered, selected
# 22731 elements left uncovered, selected
# 22728 elements left uncovered, selected
# 22725 elements left uncovered, selected
# 22722 elements left uncovered, selected
# 22719 elements left uncovered, selected
# 22716 elements left uncovered, selected
# 22713 elements left uncovered, selected
# 22710 elements left uncovered, selected
# 22707 elements left uncovered, selected
# 22704 elements left uncovered, selected
# 22701 elements left uncovered, selected
# 22698 elements left uncovered, selected
# 22695 elements left uncovered, selected
# 22692 elements left uncovered, selected
# 22689 elements left uncovered, selected
# 22686 elements left uncovered, selected
# 22683 elements left uncovered, selected
# 22680 elements left uncovered, selected
# 22677 elements left uncovered, selected
# 22674 elements left uncovered, selected
# 22671 elements left uncovered, selected
# 22668 elements left uncovered, selected
# 22665 elements left uncovered, selected
# 22662 elements left uncovered, selected
# 22659 elements left uncovered, selected
# 22656 elements left uncovered, selected
# 22653 elements left uncovered, selected
# 22650 elements left uncovered, selected
# 22647 elements left uncovered, selected
# 22644 elements left uncovered, selected
# 22641 elements left uncovered, selected
# 22638 elements left uncovered, selected
# 22635 elements left uncovered, selected
# 22632 elements left uncovered, selected
# 22629 elements left uncovered, selected
# 22626 elements left uncovered, selected
# 22623 elements left uncovered, selected
# 22620 elements left uncovered, selected
# 22617 elements left uncovered, selected
# 22614 elements left uncovered, selected
# 22611 elements left uncovered, selected
# 22608 elements left uncovered, selected
# 22605 elements left uncovered, selected
# 22602 elements left uncovered, selected
# 22599 elements left uncovered, selected
# 22596 elements left uncovered, selected
# 22593 elements left uncovered, selected
# 22590 elements left uncovered, selected
# 22587 elements left uncovered, selected
# 22584 elements left uncovered, selected
# 22581 elements left uncovered, selected
# 22578 elements left uncovered, selected
# 22575 elements left uncovered, selected
# 22572 elements left uncovered, selected
# 22569 elements left uncovered, selected
# 22566 elements left uncovered, selected
# 22563 elements left uncovered, selected
# 22560 elements left uncovered, selected
# 22557 elements left uncovered, selected
# 22554 elements left uncovered, selected
# 22551 elements left uncovered, selected
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 2
#       1 # Obtain 200 marker genes via Iterative GeneCover with an incremental size of 100 and two iterations
# ----> 2 genecover_marker_across_samples_greedy = genecover_markers_iterative = Iterative_GeneCover(incremental_sizes=[100,100], corr_mat=corr_mat_combine_across_samples, w=np.ones(corr_mat_combine_across_samples.shape[1]), greedy=True)
#
# Cell In[17], line 297, in Iterative_GeneCover(incremental_sizes, corr_mat, w, m, lambdaMin, lambdaMax, timeLimit, output, greedy)
#     295 MARKERS = []
#     296 print("Iteration 1")
# --> 297 markers = GeneCover(incremental_sizes[0], corr_mat, w = w, m =m, lambdaMax = lambdaMax, lambdaMin = lambdaMin, timeLimit = timeLimit, output=output, greedy=greedy)
#     298 selection = np.arange(corr_mat.shape[1])
#     299 MARKERS.append(markers)
#
# Cell In[17], line 226, in GeneCover(num_marker, corr_mat, w, m, interval, lambdaMax, lambdaMin, timeLimit, output, greedy)
#     224     cov_sol = selection[np.array(cov_sol.x)[:len(selection)] > 0.5]
#     225 else:
# --> 226     cov_sol = greedy_weighted_set_cover(G_v3, w)
#     227 markers = []
#     228 num_batches = G_v3.shape[0] // G_v3.shape[1]
#
# Cell In[17], line 167, in greedy_weighted_set_cover(Z, w)
#     162 selected = []
#     164 while uncovered.any():
#     165     # For each set j: how many of the still-uncovered elements it would cover?
#     166     # Z[uncovered] is an array of shape (#uncovered_elements, m)
# --> 167     cover_counts = Z[uncovered].sum(axis=0)  # shape (m,)
#     168     # zero out the ones we've already taken
#     169     cover_counts = np.where(available, cover_counts, 0)
#
# File c:\Users\An Wang\.conda\envs\vae-spatial\lib\site-packages\numpy\_core\_methods.py:53, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      51 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      52          initial=_NoValue, where=True):
# ---> 53     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# KeyboardInterrupt:
